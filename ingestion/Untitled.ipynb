# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("311_data.csv")
# Out:
# C:\Users\wizar\AppData\Local\Temp\ipykernel_34452\2993288782.py:1: DtypeWarning: Columns (0,9,19,34,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("311_data.csv")

# %%
df.head()
# Out:
#   Unique Key            Created Date             Closed Date Agency  \
# 0   62798060  10/18/2024 06:21:52 AM  10/18/2024 07:37:01 AM   NYPD
# 1   62789748  10/17/2024 11:43:42 AM  10/17/2024 01:07:13 PM   NYPD
# 2   62796743  10/18/2024 06:07:22 PM  10/18/2024 10:12:05 PM   NYPD
# 3   62795427  10/18/2024 10:35:00 AM  10/18/2024 11:50:00 AM    DEP
# 4   62798177  10/18/2024 07:24:35 AM  01/11/2025 05:05:57 AM  DOHMH
#
#                                Agency Name Problem (formerly Complaint Type)  \
# 0          New York City Police Department                   Noise - Vehicle
# 1          New York City Police Department                  Blocked Driveway
# 2          New York City Police Department                   Illegal Parking
# 3   Department of Environmental Protection               Hazardous Materials
# 4  Department of Health and Mental Hygiene                Mobile Food Vendor
#
#   Problem Detail (formerly Descriptor)        Additional Details  \
# ...

# %%
df.shape
# Out:
# (4480089, 44)
